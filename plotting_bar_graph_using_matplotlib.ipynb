# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# data cleaning, data transformation and visualization

# %%
match_data=pd.read_csv('IPL Matches 2008-2020.csv')
match_data.head(2)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1          Chennai Super Kings           bat    Chennai Super Kings   runs
#
#    result_margin eliminator method    umpire1      umpire2
# 0          140.0          N    NaN  Asad Rauf  RE Koertzen
# 1           33.0          N    NaN  MR Benson   SL Shastri

# %%
match_data['date']= pd.to_datetime(match_data['date'])
match_data['season']= match_data['date'].dt.year
match_data.head(3)
# Out:
#        id        city       date player_of_match  \
# 0  335982   Bangalore 2008-04-18     BB McCullum
# 1  335983  Chandigarh 2008-04-19      MEK Hussey
# 2  335984       Delhi 2008-04-19     MF Maharoof
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
# 2             Delhi Daredevils       Rajasthan Royals
#
#                    toss_winner toss_decision                 winner   result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders     runs
# 1          Chennai Super Kings           bat    Chennai Super Kings     runs
# ...

# %%
match_data.groupby("season")

# %%
season_group=match_data.groupby(['winner','venue'])
season_group.size().unstack().head(3)
# unstack is a function which converts rows into columns it is used for piviting 
# stack and unstack are used to make pivic tables
# Out:
# venue                Barabati Stadium  Brabourne Stadium  Buffalo Park  \
# winner
# Chennai Super Kings               NaN                1.0           1.0
# Deccan Chargers                   3.0                NaN           NaN
# Delhi Capitals                    NaN                NaN           NaN
#
# venue                De Beers Diamond Oval  Dr DY Patil Sports Academy  \
# winner
# Chennai Super Kings                    1.0                         3.0
# Deccan Chargers                        1.0                         2.0
# Delhi Capitals                         NaN                         NaN
#
# venue                Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# winner
# Chennai Super Kings                                                2.0
# Deccan Chargers                                                    NaN
# Delhi Capitals                                                     1.0
#
# venue                Dubai International Cricket Stadium  Eden Gardens  \
# ...

# %%
season_group.size().unstack(fill_value=0).head(3)
# Out:
# venue                Barabati Stadium  Brabourne Stadium  Buffalo Park  \
# winner
# Chennai Super Kings                 0                  1             1
# Deccan Chargers                     3                  0             0
# Delhi Capitals                      0                  0             0
#
# venue                De Beers Diamond Oval  Dr DY Patil Sports Academy  \
# winner
# Chennai Super Kings                      1                           3
# Deccan Chargers                          1                           2
# Delhi Capitals                           0                           0
#
# venue                Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# winner
# Chennai Super Kings                                                  2
# Deccan Chargers                                                      0
# Delhi Capitals                                                       1
#
# venue                Dubai International Cricket Stadium  Eden Gardens  \
# ...

# %%
season_group=match_data.groupby(['venue','winner'])
season_group.size().unstack(fill_value=0).head(3)
# Out:
# winner             Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# venue
# Barabati Stadium                     0                3               0
# Brabourne Stadium                    1                0               0
# Buffalo Park                         1                0               0
#
# winner             Delhi Daredevils  Gujarat Lions  Kings XI Punjab  \
# venue
# Barabati Stadium                  0              0                1
# Brabourne Stadium                 0              0                0
# Buffalo Park                      1              0                0
#
# winner             Kochi Tuskers Kerala  Kolkata Knight Riders  \
# venue
# Barabati Stadium                      0                      3
# Brabourne Stadium                     0                      0
# Buffalo Park                          0                      0
#
# winner             Mumbai Indians  Pune Warriors  Rajasthan Royals  \
# venue
# ...

# %%
match_t=match_data.copy()
match_t.replace('Rising Pune Suoergiants','Rising Pune Suoergiant',inplace=True)
match_t['winner'].unique()
# inplace redefine the original data by the changes made in that copy data
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Daredevils',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Deccan Chargers', 'Mumbai Indians',
#        'Pune Warriors', 'Kochi Tuskers Kerala', nan,
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
match_data['winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Daredevils',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Deccan Chargers', 'Mumbai Indians',
#        'Pune Warriors', 'Kochi Tuskers Kerala', nan,
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
match_data.replace('Rising Pune Suoergiants','Rising Pune Supergiant',inplace=True)
match_data[match_data['winner']=='Rising Pune Supergiant']
test=match_data.groupby(['venue','winner']).size().unstack(fill_value=0)
#finding top5 venues
topvenue=match_data['venue'].value_counts().head(5).index
test2=test.loc[topvenue].T
test2.plot(kind='bar',stacked=True,figsize=(14,6),colormap='viridis')
plt.title('Matches won by teams at Top 5 Venues')
plt.xlabel('Teams')
plt.ylabel('Wins')
plt.legend(title='venue',loc='upper left')
plt.tight_layout()
plt.show()
